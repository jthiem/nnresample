# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

from IPython.display import Audio
import scipy.io.wavfile

import nnresample

# %%
ofs, sound = scipy.io.wavfile.read('../../Databases/OLSA/Olsa/0/00456.wav')
sound = sound.T
print(ofs)
# Out:
# 44100

# %%
plt.plot(sound.T)

# %%
Audio(data=sound, rate=ofs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
newsound = nnresample.resample(sound, 16000, ofs, axis=1)
# Out:
# Generating filter (16000, 44100, 5.0, 16001)

# %%
Audio(data=newsound, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
t441 = np.arange(sound.shape[1])/44100
t16 = np.arange(newsound.shape[1])/16000

# %%
plt.figure(figsize=(17, 5))
plt.plot(t441, sound[0,:], '.-')
plt.plot(t16, newsound[0,:], '.-')
plt.axis((0.01, .015, -500, 1000))
# Out:
# (0.01, 0.015, -500, 1000)

# %%
test2 = nnresample.resample(sound, 48000, ofs, axis=1)
t48 = np.arange(test2.shape[1])/48000
# Out:
# Generating filter (48000, 44100, 5.0, 16001)

# %%
nnresample._precomputed_filters
# Out:
# {(16000,
#   44100,
#   5.0,
#   16001): array([  1.45651738e-06,   1.45821322e-06,   1.45984745e-06, ...,
#           1.45984745e-06,   1.45821322e-06,   1.45651738e-06]),
#  (48000,
#   44100,
#   5.0,
#   16001): array([  1.26647967e-06,   1.25454879e-06,   1.24211955e-06, ...,
#           1.24211955e-06,   1.25454879e-06,   1.26647967e-06])}

# %%
plt.figure(figsize=(17, 5))
plt.plot(t441, sound[0,:], '.-')
plt.plot(t48, test2[0,:], '.-')
plt.axis((0.01, .015, -500, 1000))
# Out:
# (0.01, 0.015, -500, 1000)

# %%
plt.plot(nnresample.resample(sound, 48000, 44100, 5.0, 16001, axis=1).T)
# Out:
# Filter (48000, 44100, 5.0, 16001) exists. Using it.
# ...

# %%
plt.plot(nnresample._precomputed_filters[(48000, 44100, 5.0, 16001)])

# %%
nnresample.resample?
